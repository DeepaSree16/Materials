# %% [markdown]
# #Solve the assignment problem using lambda function and list comprehension.

# %% [markdown]
# #Assignment - 22 - 02
#
# Generate the Amstrong numbers between two given numbers.
#
# Example:
#
# make_armstrong(100, 1000) => [153, 370, 371, 407]

# %%
def make_armstrong(start: int, limit: int)-> [int]:
    #Write your code here
    return

# %%
def is_armstrong(n: int)->bool:
  return sum([int(i) ** len(str(n)) for i in str(n)]) == n

# %%
def make_armstrong(start: int, limit: int)-> [int]:
  return filter(is_armstrong, range(start, limit))

# %%
list(make_armstrong(100, 1000))
# Out:
# [153, 370, 371, 407]
