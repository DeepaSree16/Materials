# %% [markdown]
# #Assignment - 23 - 01
#
# Write a function that Convert a variable name from camel case to snake case.
#
# Example :
#
# camel_case_to_snake_case("learnTechWiseTalentsprint")  => learn_tech_wise_talentsprint

# %%
def camel_case_to_snake_case(camel: str) -> str:
    #Write your code here
    return

# %%
def helper(char: str) -> str:
    return "_" + char.lower() if char.isupper() else char

def camel_case_to_snake_case(camel: str)-> str:
    return camel[0] + ''.join([helper(char) for char in camel[1:]])

camel_case_to_snake_case("learnTechWiseTalentsprint")
# Out:
# 'learn_tech_wise_talentsprint'
