# %% [markdown]
# #Assignment - 23-02
#
# Write a function that calculate the sum of unique numbers in a given list.
#
# Example:
#
# sum_of_unique_numbers([1, 2, 3, 4, 1, 5]) => 14

# %%
def sum_of_unique_numbers(num_list: [int])-> int:
    #Write your code here
    return

# %%
def sum_of_unique_numbers(num_list: [int])-> int:
    return sum([i for i in num_list if num_list.count(i) == 1])

# %%
sum_of_unique_numbers([1, 2, 3, 4, 1, 5])
# Out:
# 14

# %% [markdown]
# * Student might misunderstand unique or they might use set() to solve this problem
# * Discuss the differece between unique and distinct by explaining the following code.

# %%
def sum_of_distinct_numbers(num_list: [int])-> int:
    return sum(set(num_list))

# %%
sum_of_distinct_numbers([1, 2, 3, 4, 1, 5])
# Out:
# 15
