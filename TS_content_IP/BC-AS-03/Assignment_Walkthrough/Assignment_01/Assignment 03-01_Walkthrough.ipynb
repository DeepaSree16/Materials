# %% [markdown]
# # Assignment 03-01
# Check if a number is Curzon (2 ** n + 1) is a multiple of (2 * n + 1)

# %%
def is_curzon(z: int) -> bool:
    return (2 ** z + 1) % (2 * z + 1) == 0

# %%
is_curzon(5)
# Out:
# True
