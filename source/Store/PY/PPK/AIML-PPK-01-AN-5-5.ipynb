# %% [markdown]
# # Advanced Certification in AIML
# ## A Program by IIIT-H and TalentSprint
# ## Not for grades

# %%
#@title Run this cell to complete the setup for this Notebook
from IPython import get_ipython

ipython = get_ipython()
  
notebook= "Solution_U1W1_05_Scipy_Exercises" #name of the notebook
Answer = "Ungraded"
def setup():
#  ipython.magic("sx pip3 install torch") 
    from IPython.display import HTML, display
    display(HTML('<script src="https://dashboard.talentsprint.com/aiml/record_ip.html?traineeId={0}&recordId={1}"></script>'.format(getId(),submission_id)))
    print("Setup completed successfully")
    return

def submit_notebook():
    
    ipython.magic("notebook -e "+ notebook + ".ipynb")
    
    import requests, json, base64, datetime

    url = "https://dashboard.talentsprint.com/xp/app/save_notebook_attempts"
    if not submission_id:
      data = {"id" : getId(), "notebook" : notebook, "mobile" : getPassword()}
      r = requests.post(url, data = data)
      r = json.loads(r.text)

      if r["status"] == "Success":
          return r["record_id"]
      elif "err" in r:        
        print(r["err"])
        return None        
      else:
        print ("Something is wrong, the notebook will not be submitted for grading")
        return None

    elif getAnswer() and getComplexity() and getAdditional() and getConcepts():
      f = open(notebook + ".ipynb", "rb")
      file_hash = base64.b64encode(f.read())

      data = {"complexity" : Complexity, "additional" :Additional, 
              "concepts" : Concepts, "record_id" : submission_id, 
              "answer" : Answer, "id" : Id, "file_hash" : file_hash,
              "notebook" : notebook}

      r = requests.post(url, data = data)
      r = json.loads(r.text)
      print("Your submission is successful.")
      print("Ref Id:", submission_id)
      print("Date of submission: ", r["date"])
      print("Time of submission: ", r["time"])
      print("View your submissions: https://iiith-aiml.talentsprint.com/notebook_submissions")
     # print("For any queries/discrepancies, please connect with mentors through the chat icon in LMS dashboard.")
      return submission_id
    else: submission_id
    

def getAdditional():
  try:
    if not Additional: 
      raise NameError
    else:
      return Additional  
  except NameError:
    print ("Please answer Additional Question")
    return None

def getComplexity():
  try:
    if not Complexity:
      raise NameError
    else:
      return Complexity
  except NameError:
    print ("Please answer Complexity Question")
    return None
  
def getConcepts():
  try:
    if not Concepts:
      raise NameError
    else:
      return Concepts
  except NameError:
    print ("Please answer Concepts Question")
    return None

def getAnswer():
  try:
    if not Answer:
      raise NameError 
    else: 
      return Answer
  except NameError:
    print ("Please answer Question")
    return None

def getId():
  try: 
    return Id if Id else None
  except NameError:
    return None

def getPassword():
  try:
    return password if password else None
  except NameError:
    return None

submission_id = None
### Setup 
if getPassword() and getId():
  submission_id = submit_notebook()
  if submission_id:
    setup()
    
else:
  print ("Please complete Id and Password cells before running setup")

# %% [markdown]
# ### Q1. Write an image into the file using imwrite
#
# hint: imageio.imwrite

# %%
from scipy import misc
import imageio
f = misc.face() # It will take raccoon face and  return rgb image  
print(f.shape)  # It will give 768 x 1024 color image.

# YOUR CODE HERE
imageio.imwrite("saved.jpeg",f)
read=imageio.imread('saved.jpeg')
read.shape

# %% [markdown]
# ### Plot the image using matplotlib

# %%
import matplotlib.pyplot as plt
plt.imshow(f)
plt.show() # It will display color image

# %% [markdown]
# ### Q2. Convert the image to numpy array
#
# hint:
# 1. Load the dog image using imread
# 2. Convert the dog image to numpy array using `np.array`
# 3. Print the shape of the array

# %%
# Run this cell to download the dog image
# !wget -qq https://cdn.iiith.talentsprint.com/Test/dog.jpg

# %%
# YOUR CODE HERE
dog = imageio.imread('/content/dog.jpg')
plt.imshow(dog)
plt.show()

# %%
import numpy as np
array = np.array(dog)
array.shape

# %%
import torch
a = torch.from_numpy(array)
type(a)

# %% [markdown]
# ###  Q3. Get min and max value of dog image
#
# hint: max() and min()

# %%
# YOUR CODE HERE
dog.max(),dog.min()

# %% [markdown]
# ### Q4. Get mean of the dog image
#
# hint: mean()

# %%
# YOUR CODE HERE
dog.mean()

# %% [markdown]
# ### Q5. Create an array with 10 random values and calculate the geometric mean and harmonic mean.

# %% [markdown]
# #### Geometric mean
#
# hint: gmean

# %%
# YOUR CODE HERE
import numpy as np
from scipy.stats.mstats import gmean

array = np.random.rand(10)
print(array)
gmean(array), type(array)
array

# %% [markdown]
# #### Harmonic Mean
#
# hint: hmean

# %%
# YOUR CODE HERE
from scipy.stats.mstats import hmean
hmean(array)

# %% [markdown]
# ### Q6. Solve the below equations using scipy solver and find the values of  X, Y and Z
#
# 4X-5Y+8Z= 4,
#
# 2X-8Y+7Z=0,
#
# -5X+8Y=-5
#
# hint: linalg.solve

# %%
# YOUR CODE HERE
import numpy as np

a = [[4, -5, 8], [2, -8, 7], [-5, 8, 0]]
c = [4, 0, -5]
x = np.linalg.solve(a,c)

# %%
x

# %%
# To Verify th answers
np.allclose(np.dot(a, x), c)

# %%
# Verify for one of the equation
(2*1.5311) - (8 *  0.3319) +  (7*(-0.0580))
