# %% [markdown]
# ### Installing Required Packages

# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\ramendra\anaconda3\lib\site-packages (2.25.1)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\ramendra\anaconda3\lib\site-packages (from requests) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ramendra\anaconda3\lib\site-packages (from requests) (1.26.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ramendra\anaconda3\lib\site-packages (from requests) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\ramendra\anaconda3\lib\site-packages (from requests) (4.0.0)

# %% [markdown]
# ### Importing the packages

# %%
import os
from pathlib import Path # for handling path issues
import logging # for creating the execution log in directory
import requests # for sending http requests
import sqlite3 as _dbsql # for handling SQ-Lite3 database implementation
from http.server import BaseHTTPRequestHandler, HTTPServer # for implementing a Simple HTTP Server in Python

# %% [markdown]
# ### Execution Constants and Variables
# * For handling database and log implementation, the path constraints are handled in the below components
# * The data base file is checked if it exists, and the dB file is created.
# * The logger is configured to store the logs in a specific format

# %%
_db_root = "Database"

# %%
_dir = Path().resolve()

# %%
_log = logging.getLogger(__name__)
_log.setLevel(logging.DEBUG)
iohandler = logging.StreamHandler()
iohandler.setLevel(logging.DEBUG)
formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
iohandler.setFormatter(formatter)
_log.addHandler(iohandler)
logging.basicConfig(filename="execution_log.log", filemode='w')

# %% [markdown]
# ### Changing path to current directory (Execute only once)
# * Here, the dB file is checked for schema existence and if there is no data-base schema then a table is created with Device name as primary key and Data, timestamp as column values.

# %%
try:
    os.chdir(_dir)
    _db_root_check = os.path.isdir(_db_root)
    if not _db_root_check:
        os.makedirs(_db_root)
    _db_path = os.path.join(_dir, _db_root)
    os.chdir(_db_path)
    _log.info("database root initialised successfully")
except Exception as _initialization_exception:
    _log.critical("root path could not be initialised")
# Out:
# 2022-02-18 11:04:08,657 - __main__ - INFO - database root initialised successfully
# 2022-02-18 11:04:08,657 - __main__ - INFO - database root initialised successfully

# %% [markdown]
# # Database Initialization

# %%
try:
    _db_con = _dbsql.connect('inm_warehouse.db')
    _log.info("database inm_warehouse.db initialised successfully")
except Exception as _db_initialization:
    _log.critical("database could not be initialised")
# Out:
# 2022-02-18 11:04:09,046 - __main__ - INFO - database inm_warehouse.db initialised successfully
# 2022-02-18 11:04:09,046 - __main__ - INFO - database inm_warehouse.db initialised successfully

# %%
try:
    _db_cursor = _db_con.cursor()
    _db_cursor.execute('''CREATE TABLE warehouse
               (device_name text not null, timestamp text not null, data text not null)''')
    _log.info("database table creation successful")
except Exception as _db_exception:
    _log.warning("database table could not be initialised: " + str(_db_exception))
# Out:
# 2022-02-18 11:04:09,511 - __main__ - INFO - database table creation successful
# 2022-02-18 11:04:09,511 - __main__ - INFO - database table creation successful

# %% [markdown]
# #### Now two functions are built, one for retrieving the descriptor information from the OM2M Server and one for retrieving the data from Sq-Lite3 dB file.
#
# ### Get Descriptor for a node name from OM2M

# %%
url = "http://127.0.0.1:5089/~/in-cse/in-name/AE-TEST/Node-1/Descriptor/la"
payload={}
headers = {'X-M2M-Origin': 'admin:admin','Accept': 'application/json'}
response = requests.request("GET", url, headers=headers, data=payload)
data=eval(response.text)
data
# Out:
# {'m2m:cin': {'rn': 'cin_404229808',
#   'ty': 4,
#   'ri': '/in-cse/cin-404229808',
#   'pi': '/in-cse/cnt-434525523',
#   'ct': '20220218T080407',
#   'lt': '20220218T080407',
#   'lbl': ['Label-1', 'Label-2'],
#   'st': 0,
#   'cnf': 'text/plain:0',
#   'cs': 38,
#   'con': '[Timestamp, Occupancy-State, Distance]'}}

# %%
def get_descriptor(Node_name):
        url = "http://127.0.0.1:5089/~/in-cse/in-name/AE-TEST/" + Node_name + "/Descriptor/la"
        payload={}
        headers = {'X-M2M-Origin': 'admin:admin','Accept': 'application/json'}
        response = requests.request("GET", url, headers=headers, data=payload)
        if response.status_code != 200:
            _log.warning("device not found")
            return False, None
        data = eval(response.text)
        con = data["m2m:cin"]["con"].replace(" ", "")
        con = con.split("[")[1]
        con = con.split("]")[0]
        con = con.split(",")
        _log.info("data retrieved from om2m")
        return True, con

# %% [markdown]
# ### Get data from database for a given node-name

# %%
def get_from_db(_node_name):
    name = "'" + _node_name + "'"
    _data = _db_cursor.execute('SELECT * FROM warehouse where device_name =' + name)
    _log.info("data retrieved from db")
    return _data

# %%
name = "'" + 'Node-1' + "'"
_data = _db_cursor.execute('SELECT * FROM warehouse where device_name =' + name)
_data

# %%
for i in _data:
    print(i)
# Out:
# ('Node-1', '1645162500', '[1645162500, 1.0, 338.0]')
# ('Node-1', '1645162505', '[1645162505, 1.0, 262.0]')
# ('Node-1', '1645162511', '[1645162511, 1.0, 348.0]')
# ('Node-1', '1645162516', '[1645162516, 0.0, 303.0]')
# ('Node-1', '1645162521', '[1645162521, 1.0, 271.0]')
# ('Node-1', '1645162526', '[1645162526, 1.0, 48.0]')
# ('Node-1', '1645162531', '[1645162531, 0.0, 225.0]')
# ('Node-1', '1645162537', '[1645162537, 0.0, 107.0]')
# ('Node-1', '1645162542', '[1645162542, 1.0, 224.0]')
# ('Node-1', '1645162547', '[1645162547, 1.0, 74.0]')
# ('Node-1', '1645162552', '[1645162552, 0.0, 398.0]')
# ('Node-1', '1645162557', '[1645162557, 0.0, 43.0]')
# ('Node-1', '1645162562', '[1645162562, 1.0, 315.0]')
# ('Node-1', '1645162567', '[1645162567, 0.0, 125.0]')
# ('Node-1', '1645162572', '[1645162572, 1.0, 100.0]')
# ('Node-1', '1645162578', '[1645162578, 0.0, 79.0]')
# ('Node-1', '1645162583', '[1645162583, 1.0, 285.0]')
# ('Node-1', '1645162588', '[1645162588, 1.0, 310.0]')
# ('Node-1', '1645162593', '[1645162593, 0.0, 222.0]')
# ('Node-1', '1645162598', '[1645162598, 1.0, 208.0]')
# ('Node-1', '1645162604', '[1645162604, 0.0, 141.0]')
# ('Node-1', '1645162609', '[1645162609, 0.0, 228.0]')
# ('Node-1', '1645162614', '[1645162614, 0.0, 134.0]')
# ('Node-1', '1645162619', '[1645162619, 0.0, 21.0]')
# ('Node-1', '1645162624', '[1645162624, 0.0, 229.0]')
# ('Node-1', '1645162629', '[1645162629, 0.0, 261.0]')
# ('Node-1', '1645162635', '[1645162635, 0.0, 166.0]')
# ('Node-1', '1645162640', '[1645162640, 1.0, 236.0]')
# ('Node-1', '1645162645', '[1645162645, 1.0, 35.0]')
# ('Node-1', '1645162650', '[1645162650, 0.0, 338.0]')
# ('Node-1', '1645162656', '[1645162656, 0.0, 79.0]')
# ('Node-1', '1645162900', '[1645162900, 1.0, 174.0]')
# ('Node-1', '1645162905', '[1645162905, 0.0, 88.0]')
# ('Node-1', '1645162910', '[1645162910, 0.0, 7.0]')
# ('Node-1', '1645162916', '[1645162916, 1.0, 347.0]')
# ('Node-1', '1645162921', '[1645162921, 0.0, 121.0]')
# ('Node-1', '1645162926', '[1645162926, 1.0, 358.0]')
# ('Node-1', '1645162931', '[1645162931, 1.0, 174.0]')
# ('Node-1', '1645162936', '[1645162936, 0.0, 101.0]')
# ('Node-1', '1645162942', '[1645162942, 1.0, 151.0]')
# ('Node-1', '1645162947', '[1645162947, 1.0, 24.0]')
# ('Node-1', '1645162952', '[1645162952, 1.0, 290.0]')
# ('Node-1', '1645162957', '[1645162957, 0.0, 235.0]')
# ('Node-1', '1645162962', '[1645162962, 1.0, 191.0]')
# ('Node-1', '1645162967', '[1645162967, 0.0, 44.0]')
# ('Node-1', '1645162974', '[1645162974, 1.0, 230.0]')
# ('Node-1', '1645162979', '[1645162979, 0.0, 349.0]')
# ('Node-1', '1645162984', '[1645162984, 0.0, 115.0]')
# ('Node-1', '1645162989', '[1645162989, 1.0, 9.0]')
# ('Node-1', '1645162995', '[1645162995, 1.0, 325.0]')
# ('Node-1', '1645163000', '[1645163000, 0.0, 381.0]')
# ('Node-1', '1645163005', '[1645163005, 0.0, 216.0]')
# ('Node-1', '1645163011', '[1645163011, 1.0, 366.0]')
# ('Node-1', '1645163016', '[1645163016, 0.0, 37.0]')
# ('Node-1', '1645163022', '[1645163022, 0.0, 93.0]')
# ('Node-1', '1645163027', '[1645163027, 1.0, 309.0]')
# ('Node-1', '1645163032', '[1645163032, 0.0, 335.0]')
# ('Node-1', '1645163037', '[1645163037, 1.0, 86.0]')
# ('Node-1', '1645163042', '[1645163042, 0.0, 91.0]')
# ('Node-1', '1645163047', '[1645163047, 1.0, 357.0]')
# ('Node-1', '1645163053', '[1645163053, 1.0, 162.0]')
# ('Node-1', '1645163058', '[1645163058, 1.0, 281.0]')
# ('Node-1', '1645163063', '[1645163063, 1.0, 138.0]')
# ('Node-1', '1645163069', '[1645163069, 0.0, 51.0]')
# ('Node-1', '1645163074', '[1645163074, 1.0, 290.0]')
# ('Node-1', '1645163079', '[1645163079, 0.0, 184.0]')
# ('Node-1', '1645163084', '[1645163084, 1.0, 121.0]')
# ('Node-1', '1645163090', '[1645163090, 0.0, 250.0]')
# ('Node-1', '1645163095', '[1645163095, 0.0, 175.0]')
# ('Node-1', '1645163100', '[1645163100, 1.0, 133.0]')
# ('Node-1', '1645163105', '[1645163105, 1.0, 241.0]')
# ('Node-1', '1645163110', '[1645163110, 1.0, 285.0]')
# ('Node-1', '1645163115', '[1645163115, 1.0, 147.0]')
# ('Node-1', '1645163120', '[1645163120, 0.0, 310.0]')
# ('Node-1', '1645163126', '[1645163126, 0.0, 60.0]')
# ('Node-1', '1645163131', '[1645163131, 1.0, 396.0]')
# ('Node-1', '1645163136', '[1645163136, 1.0, 373.0]')
# ('Node-1', '1645163141', '[1645163141, 0.0, 31.0]')
# ('Node-1', '1645163146', '[1645163146, 1.0, 352.0]')
# ('Node-1', '1645163152', '[1645163152, 0.0, 16.0]')
# ('Node-1', '1645163157', '[1645163157, 0.0, 85.0]')
# ('Node-1', '1645163162', '[1645163162, 1.0, 214.0]')
# ('Node-1', '1645163167', '[1645163167, 1.0, 110.0]')
# ('Node-1', '1645163172', '[1645163172, 1.0, 127.0]')
# ('Node-1', '1645163177', '[1645163177, 0.0, 366.0]')
# ('Node-1', '1645163183', '[1645163183, 1.0, 378.0]')
# ('Node-1', '1645163188', '[1645163188, 0.0, 93.0]')
# ('Node-1', '1645163194', '[1645163194, 0.0, 378.0]')
# ('Node-1', '1645163199', '[1645163199, 0.0, 273.0]')
# ('Node-1', '1645163204', '[1645163204, 1.0, 167.0]')
# ('Node-1', '1645163210', '[1645163210, 1.0, 345.0]')
# ('Node-1', '1645163215', '[1645163215, 0.0, 37.0]')
# ('Node-1', '1645163220', '[1645163220, 0.0, 108.0]')
# ('Node-1', '1645163225', '[1645163225, 1.0, 20.0]')
# ('Node-1', '1645163230', '[1645163230, 1.0, 60.0]')
# ('Node-1', '1645163236', '[1645163236, 0.0, 80.0]')
# ('Node-1', '1645163241', '[1645163241, 0.0, 42.0]')
# ('Node-1', '1645163246', '[1645163246, 0.0, 271.0]')
# ('Node-1', '1645163251', '[1645163251, 0.0, 122.0]')
# ('Node-1', '1645163256', '[1645163256, 0.0, 133.0]')
# ('Node-1', '1645163262', '[1645163262, 1.0, 338.0]')
# ('Node-1', '1645163267', '[1645163267, 0.0, 252.0]')
# ('Node-1', '1645163272', '[1645163272, 1.0, 188.0]')
# ('Node-1', '1645163277', '[1645163277, 1.0, 93.0]')
# ('Node-1', '1645163282', '[1645163282, 0.0, 62.0]')
# ('Node-1', '1645163288', '[1645163288, 0.0, 65.0]')
# ('Node-1', '1645163293', '[1645163293, 0.0, 42.0]')
# ('Node-1', '1645163298', '[1645163298, 0.0, 124.0]')
# ('Node-1', '1645163303', '[1645163303, 1.0, 376.0]')
# ('Node-1', '1645163308', '[1645163308, 0.0, 194.0]')
# ('Node-1', '1645163313', '[1645163313, 1.0, 294.0]')
# ('Node-1', '1645163319', '[1645163319, 1.0, 174.0]')
# ('Node-1', '1645163324', '[1645163324, 0.0, 89.0]')
# ('Node-1', '1645163329', '[1645163329, 1.0, 71.0]')
# ('Node-1', '1645163334', '[1645163334, 1.0, 39.0]')
# ('Node-1', '1645163339', '[1645163339, 1.0, 124.0]')
# ('Node-1', '1645163344', '[1645163344, 1.0, 185.0]')
# ('Node-1', '1645163350', '[1645163350, 0.0, 397.0]')
# ('Node-1', '1645163355', '[1645163355, 0.0, 61.0]')

# %% [markdown]
# ### Server Class for data warehousing
# * Now a Simple HTTP Server is implemented with a post and get request.
# * Post request is used for storing the subscription data in the Sq-Lite3 DB file by implementing a data warehouse system
# * GET request is used for retrieving a data relevant to  a node name from the data warehouse through an API call.

# %%
class handler(BaseHTTPRequestHandler):
    
    
    def do_GET(self):
        
        if "/ngsi-ld/v1/entities/" in self.path:
            _node_name = self.path.split("/ngsi-ld/v1/entities/")[1]
            _parameter_list = ["node_id"]
            _om2m_status = get_descriptor(_node_name)
            
            if not _om2m_status[0]:
                self.send_response(404)
                response = "{\"type\":\"urn:dx:rs:general\",\"title\":\"Device Not Registered\",\"detail\":\"Device Not Registered\"}"
            
            else:
                _lis = []
                self.send_response(200)
                _parameter_list += _om2m_status[1]
                _log.info(_parameter_list)
                response = "{\"title\": \"Successful operation\", \"type\": \"urn:dx:rs:success\", \"results\": ["
                
                _data = get_from_db(_node_name)
                for row in _data:
                    _log.info(row)
                    _lis += [row]
                _ordered_data = list(reversed(_lis))
                length_of_data = len(_ordered_data)
                for row_id in range(length_of_data):
                    _current_row = [_node_name]
                    _current_row += eval(list(_ordered_data[row_id])[2])
                    response += "{"
                    _data_length = len(_parameter_list)
                    
                    for parameter_id in range(_data_length):
                        response += "\"" + _parameter_list[parameter_id] + "\":" + "\"" + str(_current_row[parameter_id])
                        
                        if parameter_id == _data_length -1:
                            response += "\""
                        
                        else:
                            response += "\","
                    
                    if row_id == length_of_data -1:
                        response += "}"
                    
                    else:
                        response += "},"
                
                response += "]}"
                _log.info("data formatting successsful")
                    
        else:
            _log.warning("url-end point not found")
            self.send_response(404)
            response = "{\"type\":\"urn:dx:rs:general\",\"title\":\"NotFound\",\"detail\":\"NotFound\"}"
            
        self.send_header('Content-type','application/json')
        self.end_headers()
        self.wfile.write(bytes(response, "utf8"))
    
    def do_POST(self):
        self.data_string = self.rfile.read(int(self.headers['Content-Length'])).decode("utf-8")
        self.send_response(200)
        self.send_header('Content-type','text/html')
        self.end_headers()
        try:
            var = eval(self.data_string.replace("false", "False" ))
            _con = eval(var["m2m:sgn"]["m2m:nev"]["m2m:rep"]["m2m:cin"]["con"])
            _lbl = var["m2m:sgn"]["m2m:nev"]["m2m:rep"]["m2m:cin"]["lbl"]
            _values = (str(_lbl[0]), str(_con[0]), str(_con))
            _query = "INSERT INTO warehouse VALUES " + str(_values)
            _db_cursor.execute(_query)
            _log.info("data stored with query: " + str(_query))
        except Exception as ioerror:
            _log.critical("data storage failed with exception: " + str(ioerror))
        
        message = "{\"Status\": 200}"
        self.wfile.write(bytes(message, "utf8"))

# %%
with HTTPServer(('', 5091), handler) as server:
        server.serve_forever()
# Out:
# 2022-02-18 11:04:37,350 - __main__ - INFO - data retrieved from om2m
# 2022-02-18 11:04:37,350 - __main__ - INFO - data retrieved from om2m
# 127.0.0.1 - - [18/Feb/2022 11:04:37] "GET /ngsi-ld/v1/entities/Node-1 HTTP/1.1" 200 -
# 2022-02-18 11:04:37,354 - __main__ - INFO - ['node_id', 'Timestamp', 'Occupancy-State', 'Distance']
# 2022-02-18 11:04:37,354 - __main__ - INFO - ['node_id', 'Timestamp', 'Occupancy-State', 'Distance']
# 2022-02-18 11:04:37,359 - __main__ - INFO - data retrieved from db
# 2022-02-18 11:04:37,359 - __main__ - INFO - data retrieved from db
# 2022-02-18 11:04:37,367 - __main__ - INFO - data formatting successsful
# 2022-02-18 11:04:37,367 - __main__ - INFO - data formatting successsful
# 2022-02-18 11:05:00,828 - __main__ - INFO - data retrieved from om2m
# 2022-02-18 11:05:00,828 - __main__ - INFO - data retrieved from om2m
# 127.0.0.1 - - [18/Feb/2022 11:05:00] "GET /ngsi-ld/v1/entities/Node-1 HTTP/1.1" 200 -
# 2022-02-18 11:05:00,837 - __main__ - INFO - ['node_id', 'Timestamp', 'Occupancy-State', 'Distance']
# 2022-02-18 11:05:00,837 - __main__ - INFO - ['node_id', 'Timestamp', 'Occupancy-State', 'Distance']
# 2022-02-18 11:05:00,842 - __main__ - INFO - data retrieved from db
# 2022-02-18 11:05:00,842 - __main__ - INFO - data retrieved from db
# 2022-02-18 11:05:00,846 - __main__ - INFO - data formatting successsful
# 2022-02-18 11:05:00,846 - __main__ - INFO - data formatting successsful
# 127.0.0.1 - - [18/Feb/2022 11:05:03] "POST / HTTP/1.1" 200 -
# 2022-02-18 11:05:03,594 - __main__ - INFO - data stored with query: INSERT INTO warehouse VALUES ('Node-1', '1645162500', '[1645162500, 1.0, 338.0]')
# 2022-02-18 11:05:03,594 - __main__ - INFO - data stored with query: INSERT INTO warehouse VALUES ('Node-1', '1645162500', '[1645162500, 1.0, 338.0]')
# 127.0.0.1 - - [18/Feb/2022 11:05:08] "POST / HTTP/1.1" 200 -
# 2022-02-18 11:05:08,584 - __main__ - INFO - data stored with query: INSERT INTO warehouse VALUES ('Node-1', '1645162505', '[1645162505, 1.0, 262.0]')
# 2022-02-18 11:05:08,584 - __main__ - INFO - data stored with query: INSERT INTO warehouse VALUES ('Node-1', '1645162505', '[1645162505, 1.0, 262.0]')
# 127.0.0.1 - - [18/Feb/2022 11:05:13] "POST / HTTP/1.1" 200 -
# 2022-02-18 11:05:13,850 - __main__ - INFO - data stored with query: INSERT INTO warehouse VALUES ('Node-1', '1645162511', '[1645162511, 1.0, 348.0]')
# 2022-02-18 11:05:13,850 - __main__ - INFO - data stored with query: INSERT INTO warehouse VALUES ('Node-1', '1645162511', '[1645162511, 1.0, 348.0]')
# 127.0.0.1 - - [18/Feb/2022 11:05:18] "POST / HTTP/1.1" 200 -
# 2022-02-18 11:05:18,942 - __main__ - INFO - data stored with query: INSERT INTO warehouse VALUES ('Node-1', '1645162516', '[1645162516, 0.0, 303.0]')
# 2022-02-18 11:05:18,942 - __main__ - INFO - data stored with query: INSERT INTO warehouse VALUES ('Node-1', '1645162516', '[1645162516, 0.0, 303.0]')
# 2022-02-18 11:05:23,818 - __main__ - INFO - data retrieved from om2m
# 2022-02-18 11:05:23,818 - __main__ - INFO - data retrieved from om2m
# 127.0.0.1 - - [18/Feb/2022 11:05:23] "GET /ngsi-ld/v1/entities/Node-1 HTTP/1.1" 200 -
# 2022-02-18 11:05:23,824 - __main__ - INFO - ['node_id', 'Timestamp', 'Occupancy-State', 'Distance']
# 2022-02-18 11:05:23,824 - __main__ - INFO - ['node_id', 'Timestamp', 'Occupancy-State', 'Distance']
# 2022-02-18 11:05:23,828 - __main__ - INFO - data retrieved from db
# 2022-02-18 11:05:23,828 - __main__ - INFO - data retrieved from db
# 2022-02-18 11:05:23,832 - __main__ - INFO - ('Node-1', '1645162500', '[1645162500, 1.0, 338.0]')
# 2022-02-18 11:05:23,832 - __main__ - INFO - ('Node-1', '1645162500', '[1645162500, 1.0, 338.0]')
# 2022-02-18 11:05:23,837 - __main__ - INFO - ('Node-1', '1645162505', '[1645162505, 1.0, 262.0]')
# 2022-02-18 11:05:23,837 - __main__ - INFO - ('Node-1', '1645162505', '[1645162505, 1.0, 262.0]')
# 2022-02-18 11:05:23,841 - __main__ - INFO - ('Node-1', '1645162511', '[1645162511, 1.0, 348.0]')
# 2022-02-18 11:05:23,841 - __main__ - INFO - ('Node-1', '1645162511', '[1645162511, 1.0, 348.0]')
- __main__ - INFO - data stored with query: INSERT INTO warehouse VALUES ('Node-1', '1645163047', '[1645163047, 1.0, 357.0]')
# 127.0.0.1 - - [18/Feb/2022 11:14:15] "POST / HTTP/1.1" 200 -
# 2022-02-18 11:14:15,590 - __main__ - INFO - data stored with query: INSERT INTO warehouse VALUES ('Node-1', '1645163053', '[1645163053, 1.0, 162.0]')
# 2022-02-18 11:14:15,590 - __main__ - INFO - data stored with query: INSERT INTO warehouse VALUES ('Node-1', '1645163053', '[1645163053, 1.0, 162.0]')
# 127.0.0.1 - - [18/Feb/2022 11:14:20] "POST / HTTP/1.1" 200 -
# 2022-02-18 11:14:20,806 - __main__ - INFO - data stored with query: INSERT INTO warehouse VALUES ('Node-1', '1645163058', '[1645163058, 1.0, 281.0]')
# 2022-02-18 11:14:20,806 - __main__ - INFO - data stored with query: INSERT INTO warehouse VALUES ('Node-1', '1645163058', '[1645163058, 1.0, 281.0]')
# 127.0.0.1 - - [18/Feb/2022 11:14:27] "POST / HTTP/1.1" 200 -
# 2022-02-18 11:14:27,042 - __main__ - INFO - data stored with query: INSERT INTO warehouse VALUES ('Node-1', '1645163063', '[1645163063, 1.0, 138.0]')
# 2022-02-18 11:14:27,042 - __main__ - INFO - data stored with query: INSERT INTO warehouse VALUES ('Node-1', '1645163063', '[1645163063, 1.0, 138.0]')
# 127.0.0.1 - - [18/Feb/2022 11:14:32] "POST / HTTP/1.1" 200 -
# 2022-02-18 11:14:32,198 - __main__ - INFO - data stored with query: INSERT INTO warehouse VALUES ('Node-1', '1645163069', '[1645163069, 0.0, 51.0]')
# 2022-02-18 11:14:32,198 - __main__ - INFO - data stored with query: INSERT INTO warehouse VALUES ('Node-1', '1645163069', '[1645163069, 0.0, 51.0]')
# 127.0.0.1 - - [18/Feb/2022 11:14:37] "POST / HTTP/1.1" 200 -
# 2022-02-18 11:14:37,294 - __main__ - INFO - data stored with query: INSERT INTO warehouse VALUES ('Node-1', '1645163074', '[1645163074, 1.0, 290.0]')
# 2022-02-18 11:14:37,294 - __main__ - INFO - data stored with query: INSERT INTO warehouse VALUES ('Node-1', '1645163074', '[1645163074, 1.0, 290.0]')
# 127.0.0.1 - - [18/Feb/2022 11:14:42] "POST / HTTP/1.1" 200 -
# 2022-02-18 11:14:42,374 - __main__ - INFO - data stored with query: INSERT INTO warehouse VALUES ('Node-1', '1645163079', '[1645163079, 0.0, 184.0]')
# 2022-02-18 11:14:42,374 - __main__ - INFO - data stored with query: INSERT INTO warehouse VALUES ('Node-1', '1645163079', '[1645163079, 0.0, 184.0]')
# 127.0.0.1 - - [18/Feb/2022 11:14:47] "POST / HTTP/1.1" 200 -
# 2022-02-18 11:14:47,458 - __main__ - INFO - data stored with query: INSERT INTO warehouse VALUES ('Node-1', '1645163084', '[1645163084, 1.0, 121.0]')
# 2022-02-18 11:14:47,458 - __main__ - INFO - data stored with query: INSERT INTO warehouse VALUES ('Node-1', '1645163084', '[1645163084, 1.0, 121.0]')
# 127.0.0.1 - - [18/Feb/2022 11:14:52] "POST / HTTP/1.1" 200 -
# 2022-02-18 11:14:52,530 - __main__ - INFO - data stored with query: INSERT INTO warehouse VALUES ('Node-1', '1645163090', '[1645163090, 0.0, 250.0]')
# 2022-02-18 11:14:52,530 - __main__ - INFO - data stored with query: INSERT INTO warehouse VALUES ('Node-1', '1645163090', '[1645163090, 0.0, 250.0]')
# 127.0.0.1 - - [18/Feb/2022 11:14:57] "POST / HTTP/1.1" 200 -
# 2022-02-18 11:14:57,711 - __main__ - INFO - data stored with query: INSERT INTO warehouse VALUES ('Node-1', '1645163095', '[1645163095, 0.0, 175.0]')
# 2022-02-18 11:14:57,711 - __main__ - INFO - data stored with query: INSERT INTO warehouse VALUES ('Node-1', '1645163095', '[1645163095, 0.0, 175.0]')
# 127.0.0.1 - - [18/Feb/2022 11:15:02] "POST / HTTP/1.1" 200 -
# 2022-02-18 11:15:02,803 - __main__ - INFO - data stored with query: INSERT INTO warehouse VALUES ('Node-1', '1645163100', '[1645163100, 1.0, 133.0]')
# 2022-02-18 11:15:02,803 - __main__ - INFO - data stored with query: INSERT INTO warehouse VALUES ('Node-1', '1645163100', '[1645163100, 1.0, 133.0]')
# 127.0.0.1 - - [18/Feb/2022 11:15:07] "POST / HTTP/1.1" 200 -
# 2022-02-18 11:15:07,896 - __main__ - INFO - data stored with query: INSERT INTO warehouse VALUES ('Node-1', '1645163105', '[1645163105, 1.0, 241.0]')
# 2022-02-18 11:15:07,896 - __main__ - INFO - data stored with query: INSERT INTO warehouse VALUES ('Node-1', '1645163105', '[1645163105, 1.0, 241.0]')
# 127.0.0.1 - - [18/Feb/2022 11:15:13] "POST / HTTP/1.1" 200 -
# 2022-02-18 11:15:13,167 - __main__ - INFO - data stored with query: INSERT INTO warehouse VALUES ('Node-1', '1645163110', '[1645163110, 1.0, 285.0]')
# 2022-02-18 11:15:13,167 - __main__ - INFO - data stored with query: INSERT INTO warehouse VALUES ('Node-1', '1645163110', '[1645163110, 1.0, 285.0]')
# 2022-02-18 11:15:16,734 - __main__ - INFO - data retrieved from om2m
# 2022-02-18 11:15:16,734 - __main__ - INFO - data retrieved from om2m
# 127.0.0.1 - - [18/Feb/2022 11:15:16] "GET /ngsi-ld/v1/entities/Node-1 HTTP/1.1" 200 -
# 2022-02-18 11:15:16,739 - __main__ - INFO - ['node_id', 'Timestamp', 'Occupancy-State', 'Distance']
# 2022-02-18 11:15:16,739 - __main__ - INFO - ['node_id', 'Timestamp', 'Occupancy-State', 'Distance']
# 2022-02-18 11:15:16,745 - __main__ - INFO - data retrieved from db
# 2022-02-18 11:15:16,745 - __main__ - INFO - data retrieved from db
# 2022-02-18 11:15:16,750 - __main__ - INFO - ('Node-1', '1645162500', '[1645162500, 1.0, 338.0]')
# 2022-02-18 11:15:16,750 - __main__ - INFO - ('Node-1', '1645162500', '[1645162500, 1.0, 338.0]')
# 2022-02-18 11:15:16,752 - __main__ - INFO - ('Node-1', '1645162505', '[1645162505, 1.0, 262.0]')
# 2022-02-18 11:15:16,752 - __main__ - INFO - ('Node-1', '1645162505', '[1645162505, 1.0, 262.0]')
- __main__ - INFO - data stored with query: INSERT INTO warehouse VALUES ('Node-1', '1645163293', '[1645163293, 0.0, 42.0]')
# 2022-02-18 11:18:15,717 - __main__ - INFO - data stored with query: INSERT INTO warehouse VALUES ('Node-1', '1645163293', '[1645163293, 0.0, 42.0]')
# 127.0.0.1 - - [18/Feb/2022 11:18:20] "POST / HTTP/1.1" 200 -
# 2022-02-18 11:18:20,868 - __main__ - INFO - data stored with query: INSERT INTO warehouse VALUES ('Node-1', '1645163298', '[1645163298, 0.0, 124.0]')
# 2022-02-18 11:18:20,868 - __main__ - INFO - data stored with query: INSERT INTO warehouse VALUES ('Node-1', '1645163298', '[1645163298, 0.0, 124.0]')
# 127.0.0.1 - - [18/Feb/2022 11:18:26] "POST / HTTP/1.1" 200 -
# 2022-02-18 11:18:26,054 - __main__ - INFO - data stored with query: INSERT INTO warehouse VALUES ('Node-1', '1645163303', '[1645163303, 1.0, 376.0]')
# 2022-02-18 11:18:26,054 - __main__ - INFO - data stored with query: INSERT INTO warehouse VALUES ('Node-1', '1645163303', '[1645163303, 1.0, 376.0]')
# 127.0.0.1 - - [18/Feb/2022 11:18:31] "POST / HTTP/1.1" 200 -
# 2022-02-18 11:18:31,284 - __main__ - INFO - data stored with query: INSERT INTO warehouse VALUES ('Node-1', '1645163308', '[1645163308, 0.0, 194.0]')
# 2022-02-18 11:18:31,284 - __main__ - INFO - data stored with query: INSERT INTO warehouse VALUES ('Node-1', '1645163308', '[1645163308, 0.0, 194.0]')
# 127.0.0.1 - - [18/Feb/2022 11:18:36] "POST / HTTP/1.1" 200 -
# 2022-02-18 11:18:36,528 - __main__ - INFO - data stored with query: INSERT INTO warehouse VALUES ('Node-1', '1645163313', '[1645163313, 1.0, 294.0]')
# 2022-02-18 11:18:36,528 - __main__ - INFO - data stored with query: INSERT INTO warehouse VALUES ('Node-1', '1645163313', '[1645163313, 1.0, 294.0]')
# 127.0.0.1 - - [18/Feb/2022 11:18:41] "POST / HTTP/1.1" 200 -
# 2022-02-18 11:18:41,707 - __main__ - INFO - data stored with query: INSERT INTO warehouse VALUES ('Node-1', '1645163319', '[1645163319, 1.0, 174.0]')
# 2022-02-18 11:18:41,707 - __main__ - INFO - data stored with query: INSERT INTO warehouse VALUES ('Node-1', '1645163319', '[1645163319, 1.0, 174.0]')
# 127.0.0.1 - - [18/Feb/2022 11:18:46] "POST / HTTP/1.1" 200 -
# 2022-02-18 11:18:46,860 - __main__ - INFO - data stored with query: INSERT INTO warehouse VALUES ('Node-1', '1645163324', '[1645163324, 0.0, 89.0]')
# 2022-02-18 11:18:46,860 - __main__ - INFO - data stored with query: INSERT INTO warehouse VALUES ('Node-1', '1645163324', '[1645163324, 0.0, 89.0]')
# 127.0.0.1 - - [18/Feb/2022 11:18:51] "POST / HTTP/1.1" 200 -
# 2022-02-18 11:18:51,955 - __main__ - INFO - data stored with query: INSERT INTO warehouse VALUES ('Node-1', '1645163329', '[1645163329, 1.0, 71.0]')
# 2022-02-18 11:18:51,955 - __main__ - INFO - data stored with query: INSERT INTO warehouse VALUES ('Node-1', '1645163329', '[1645163329, 1.0, 71.0]')
# 127.0.0.1 - - [18/Feb/2022 11:18:57] "POST / HTTP/1.1" 200 -
# 2022-02-18 11:18:57,131 - __main__ - INFO - data stored with query: INSERT INTO warehouse VALUES ('Node-1', '1645163334', '[1645163334, 1.0, 39.0]')
# 2022-02-18 11:18:57,131 - __main__ - INFO - data stored with query: INSERT INTO warehouse VALUES ('Node-1', '1645163334', '[1645163334, 1.0, 39.0]')
# 127.0.0.1 - - [18/Feb/2022 11:19:02] "POST / HTTP/1.1" 200 -
# 2022-02-18 11:19:02,339 - __main__ - INFO - data stored with query: INSERT INTO warehouse VALUES ('Node-1', '1645163339', '[1645163339, 1.0, 124.0]')
# 2022-02-18 11:19:02,339 - __main__ - INFO - data stored with query: INSERT INTO warehouse VALUES ('Node-1', '1645163339', '[1645163339, 1.0, 124.0]')
# 127.0.0.1 - - [18/Feb/2022 11:19:07] "POST / HTTP/1.1" 200 -
# 2022-02-18 11:19:07,524 - __main__ - INFO - data stored with query: INSERT INTO warehouse VALUES ('Node-1', '1645163344', '[1645163344, 1.0, 185.0]')
# 2022-02-18 11:19:07,524 - __main__ - INFO - data stored with query: INSERT INTO warehouse VALUES ('Node-1', '1645163344', '[1645163344, 1.0, 185.0]')
# 127.0.0.1 - - [18/Feb/2022 11:19:12] "POST / HTTP/1.1" 200 -
# 2022-02-18 11:19:12,627 - __main__ - INFO - data stored with query: INSERT INTO warehouse VALUES ('Node-1', '1645163350', '[1645163350, 0.0, 397.0]')
# 2022-02-18 11:19:12,627 - __main__ - INFO - data stored with query: INSERT INTO warehouse VALUES ('Node-1', '1645163350', '[1645163350, 0.0, 397.0]')
# 127.0.0.1 - - [18/Feb/2022 11:19:17] "POST / HTTP/1.1" 200 -
# 2022-02-18 11:19:17,887 - __main__ - INFO - data stored with query: INSERT INTO warehouse VALUES ('Node-1', '1645163355', '[1645163355, 0.0, 61.0]')
# 2022-02-18 11:19:17,887 - __main__ - INFO - data stored with query: INSERT INTO warehouse VALUES ('Node-1', '1645163355', '[1645163355, 0.0, 61.0]')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-57d4ff07e607> in <module>
#       1 with HTTPServer(('', 5091), handler) as server:
# ----> 2         server.serve_forever()
#
# ~\anaconda3\lib\socketserver.py in serve_forever(self, poll_interval)
#     230
#     231                 while not self.__shutdown_request:
# --> 232                     ready = selector.select(poll_interval)
#     233                     # bpo-35017: shutdown() called during select(), exit immediately.
#     234                     if self.__shutdown_request:
#
# ~\anaconda3\lib\selectors.py in select(self, timeout)
#     321         ready = []
#     322         try:
# --> 323             r, w, _ = self._select(self._readers, self._writers, [], timeout)
#     324         except InterruptedError:
#     325             return ready
#
# ~\anaconda3\lib\selectors.py in _select(self, r, w, _, timeout)
#     312     if sys.platform == 'win32':
#     313         def _select(self, r, w, _, timeout=None):
# --> 314             r, w, x = select.select(r, w, w, timeout)
#     315             return r, w + x, []
#     316     else:
#
# KeyboardInterrupt:
