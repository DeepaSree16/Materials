# %% [markdown]
# # Advanced Certification in AIML
# ## A Program by IIIT-H and TalentSprint

# %% [markdown]
# ###Not for Grading

# %% [markdown]
# ####Classification using MLP

# %% [markdown]
# The objective of this case study is to understand classification i.e., if the price of the house is low (0) or high (1) using Multilayer perceptron.

# %%
! wget https://cdn.talentsprint.com/aiml/Experiment_related_data/Iris.csv

# %% [markdown]
# ### Importing required packages

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# The attributes of related House price are stored in "X" as features and the House price whether it is low (0) or high (1) are stored in "y" as labels.

# %%
X = np.array([[3, 2000, 90], [2, 800, 143], [2, 850, 167], [1, 550, 267], [4, 2000, 396]])
y = np.array([1, 0, 0, 0 , 1])

# %% [markdown]
# ###Standard scaling the features "X"

# %%
ss = StandardScaler()
ss.fit(X)
X = ss.transform(X)
X

# %% [markdown]
# ### MLP Classifier

# %%
from sklearn.neural_network import MLPClassifier

# %%
clf = MLPClassifier(activation= 'relu', solver= 'sgd',max_iter= 5000, hidden_layer_sizes= (4), learning_rate_init= 0.01, tol= 1e-7, verbose= 1, random_state= 123)

# %%
clf.fit(X, y)

# %% [markdown]
# ###Plotting Loss vs Epochs graph

# %%
plt.plot(clf.loss_curve_)
plt.title('Loss vs Epoch')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()

# %%
pred = clf.predict(X)

# %%
import pandas as pd
df = pd.DataFrame({'Actaul': y, 'Predicted': pred})

# %%
df
