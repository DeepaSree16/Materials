# %% [markdown]
# # Advanced Certification in AIML
# ## A Program by IIIT-H and TalentSprint

# %% [markdown]
# ## Learning Objective:

# %% [markdown]
# At the end of the experiment,  you will be able to :
#
#
# * understand Multi-Layer Perceptron

# %%
! wget https://cdn.iiith.talentsprint.com/aiml/Experiment_related_data/social_advertising.csv

# %% [markdown]
# ### Import the required packages

# %%
import numpy as np
import pandas as pd
from sklearn.neural_network import MLPClassifier
import matplotlib.pyplot as plt

# %%
adv = pd.read_csv("social_advertising.csv")
print(adv.shape)
adv.head()
# Out:
# (400, 5)
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
adv = adv.drop(["User ID", "Gender"], axis = 1)
adv.head()
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %%
# Extract features and labels
X = adv.drop("Purchased", axis=1)
y = adv["Purchased"]
X = np.asarray(X)
y = np.asarray(y)

# %%
# Standardize the features
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_std = scaler.fit_transform(X)

# %%
# Split the data into train and test sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test  = train_test_split(X_std, y, test_size = 0.25, random_state=42)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (300, 2) (100, 2) (300,) (100,)

# %%
model = MLPClassifier()
# Fit the data into the model
model.fit(X_train, y_train)
# Predict the labels for test data
accuracy = model.score(X_test, y_test)
print("Accuracy of MLP Classifier", accuracy)
# Out:
# Accuracy of MLP Classifier 0.95

# %%
from mlxtend.plotting import plot_decision_regions

fig = plot_decision_regions(X=X_test, y=y_test, clf=model)
plt.title("Multi-layer Perceptron Classification")
plt.show()
