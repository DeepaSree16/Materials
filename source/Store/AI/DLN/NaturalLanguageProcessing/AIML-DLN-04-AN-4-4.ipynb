# %% [markdown]
# # Advanced Certification in AIML
# ## A Program by IIIT-H and TalentSprint

# %% [markdown]
# ### Not for Grading

# %% [markdown]
# ## Learning Objective

# %% [markdown]
# At the end of the experiment, you will be able to understand :
#
# * N-gram representation

# %% [markdown]
# <img src="https://www.researchgate.net/profile/Mark_Myslin2/publication/256290162/figure/fig4/AS:297867420946436@1448028535633/N-gram-text-representation.png" width=600 height=400>

# %% [markdown]
# <img src="https://www.researchgate.net/profile/Mark_Myslin2/publication/256290162/figure/fig5/AS:297867420946437@1448028535824/Machine-learning-experiment-workflow.png" width=700 height=750>

# %% [markdown]
# Consider the sentence and apply ngram to pick uni-grams, bi-grams, tri-grams and fourgrams.
#
#
# Click  [here](https://www.nltk.org/api/nltk.util.html) to know more about ngrams

# %%
from nltk import ngrams  

Sentences =''' One Cent, Two Cents, Old Cent, New Cent: All About Money (Cat in the Hat's Learning Library)
        Inside Your Outside: All About the Human Body (Cat in the Hat's Learning Library)
        Oh, The Things You Can Do That Are Good for You: All About Staying Healthy (Cat in the Hat's Learning Library)
        On Beyond Bugs: All About Insects (Cat in the Hat's Learning Library)
        There's No Place Like Space: All About Our Solar System (Cat in the Hat's Learning Library)'''

unigram = list(ngrams(Sentences.lower().split(), 1))       # one word sequence
bigram = list(ngrams(Sentences.lower().split(), 2))        # two word sequence
trigram = list(ngrams(Sentences.lower().split(), 3))       # three word sequence
fourgram = list(ngrams(Sentences.lower().split(), 4))      # four word sequence

# %%
unigram[0:15]

# %%
bigram[0:20]

# %%
trigram[0:10]

# %%
fourgram[0:10]
