# %% [markdown]
# # TalentSprint

# %% [markdown]
# ## Objectives
#
# At the end of the experiment, you will be able to
#
# * understand logistic regression
# * apply logistic regression on any dataset to extract meaningful insights from it

# %% [markdown]
# ## Dataset
#
# The dataset choosen for this experiment is synthatic data.

# %% [markdown]
# **Importing Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# **Generating data**

# %%
num_observations = 1000

# %%
x1 = np.random.multivariate_normal([0, 0], [[1, .75],[.75, 1]], num_observations)
x2 = np.random.multivariate_normal([1, 4], [[1, .75],[.75, 1]], num_observations)

# %%
features = np.vstack((x1, x2)).astype(np.float32)

labels = np.hstack((np.zeros(num_observations),
                              np.ones(num_observations)))

# %% [markdown]
# **Plotting the data**

# %%
# PLOT RANDOMLY GENERATED DATA 

plt.figure(figsize=(20,8))
plt.subplot(131)
plt.scatter(features[:, 0], features[:, 1],
            c = labels, alpha = .4)
plt.subplot(132)
plt.scatter(features[:, 0], labels,
            c = labels, alpha = .4)
plt.subplot(133)
plt.scatter(features[:, 1], labels,
            c = labels, alpha = .4)
plt.show()

# %% [markdown]
# **Splitting the data into train and test sets**

# %%
X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.33)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((1340, 2), (660, 2), (1340,), (660,))

# %% [markdown]
# **Applying logistic regression**

# %%
clf = LogisticRegression()
clf.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
y_pred_test = clf.predict(X_test)
y_pred_train = clf.predict(X_train)

# %% [markdown]
# **Calculating accuracy**

# %%
from sklearn.metrics import accuracy_score

print(f"Train accuracy: {accuracy_score(y_train, y_pred_train)*100:.2f}")
print(f"Test accuracy: {accuracy_score(y_test, y_pred_test)*100:.2f}")
# Out:
# Train accuracy: 99.63
# Test accuracy: 99.70

# %%
from sklearn.neighbors import KNeighborsClassifier

# train_acc = []
# test_acc = []
# k_range = list(range(1, 100, 2)) 

# for k in k_range:
#     model = KNeighborsClassifier(k)
#     model.fit(X_train, y_train)
#     y_pred_test = model.predict(X_test)
#     y_pred_train = model.predict(X_train)
#     train_acc.append(accuracy_score(y_train, y_pred_train))
#     test_acc.append(accuracy_score(y_test, y_pred_test))
    
plt.figure(figsize=(20, 6))
plt.subplot(121)
plt.plot(k_range, train_acc)
plt.xlim(20, 25)
plt.subplot(122)
plt.plot(k_range, test_acc)
plt.xlim(20, 25)
plt.show()

# %%
model = KNeighborsClassifier(23)
model.fit(X_train, y_train)
y_pred_test = model.predict(X_test)
y_pred_train = model.predict(X_train)
print(f"Train accuracy: {accuracy_score(y_train, y_pred_train)*100:.2f}")
print(f"Train accuracy: {accuracy_score(y_test, y_pred_test)*100:.2f}")
# Out:
# Train accuracy: 99.70
# Train accuracy: 99.70
